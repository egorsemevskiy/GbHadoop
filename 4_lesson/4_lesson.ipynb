# %% [markdown]
# # Первая часть задания -- форматы данных

# %%
from IPython.display import Image

# %%
Image("Screenshot from 2020-04-15 16-29-10.png")

# %% [markdown]
# # Вторая часть задания -- SQOOP ---
# Простое задание довольно :)

# %% [markdown]
# ##  Создать отдельную БД в HIve

# %%
CREATE DATABASE student3_8_db_for_4_lesson;

# %% [markdown]
# ## Посмотреть при помощи SQOOP содержимое БД в POsgresql

# %% [markdown]
# sqoop list-databases --connect jdbc:postgresql://node3.novalocal/pg_db --username exporter --password exporter_pass

# %% [markdown]
# ## Копирую таблицу в свою базу данных

# %% [markdown]
# sqoop import --connect jdbc:postgresql://node3.novalocal/pg_db --username exporter --password exporter_pass --table sales_large -split-by orderid --hive-import --hive-database student3_8_db_for_4_lesson --hive-table sales_large --as-parquetfile
